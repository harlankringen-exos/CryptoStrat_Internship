# %% [markdown]
# ## Trade Distribution
#
# In this notebook we look at the distribution of number of trades on the futures over aggregated futures (May expiry, June expiry,... ) over different time scales.

# %%
import pandas as pd
import numpy as np
import calendar
from datetime import datetime

import matplotlib.pyplot as plt
import mpld3

# %%
futures = '''BTCH0,BTCJ0,BTCK0,BTCM0,BTCN0,BTCQ0,BTCU0,BTCV0,BTCX0'''.split(',')

df = pd.DataFrame()
for f in futures:
    df2 = pd.read_csv(f"../data_dumps/{f}_Curncy.csv", parse_dates=["time"])
    df2["index"] = df2.index
    df2 = df2.set_index('time')
    df2.index = df2.index.tz_localize('UTC')
    df2 = df2[(df2["conditionCodes"] == "TSUM") | (df2["conditionCodes"] == "ST")]
    #df2 = df2.groupby('size').resample('1h').sum()
    if df.empty:
        df = df2
    else:
        df = pd.concat([df,df2],axis=0)#.groupby('time', sort=False)['size'].sum(min_count=1).reset_index()

# %%
df[["size"]].groupby(pd.Grouper(freq="D")).sum()#.reset_index()
# Out:
#                            size
# time
# 2019-10-01 00:00:00+00:00     9
# 2019-10-02 00:00:00+00:00     5
# 2019-10-03 00:00:00+00:00    24
# 2019-10-04 00:00:00+00:00     0
# 2019-10-05 00:00:00+00:00     0
# ...                         ...
# 2020-07-26 00:00:00+00:00   675
# 2020-07-27 00:00:00+00:00  9518
# 2020-07-28 00:00:00+00:00  4744
# 2020-07-29 00:00:00+00:00  4449
# 2020-07-30 00:00:00+00:00   539
#
# [304 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(12,8))
plt.hist(df["size"])
mpld3.display(fig)
#df.describe()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el4788140021753666064745415759"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el4788140021753666064745415759", {"width": 864.0, "height": 576.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-175.05000000000004, 3698.05], "ylim": [0.0, 572860.05], "xdomain": [-175.05000000000004, 3698.05], "ydomain": [0.0, 572860.05], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 10, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el4788140021753664784", "lines": [], "paths": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021821324624", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021753663568", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675160656", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data02", "xindex": 2, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675161488", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 2, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675160976", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 3, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675163600", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 4, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675163472", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 5, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675163536", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 6, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675162320", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data02", "xindex": 3, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675161808", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}], "markers": [], "texts": [], "collections": [], "images": [], "sharex": [], "sharey": []}], "data": {"data01": [[0.9999999999999716, 0.0], [353.1, 0.0], [353.1, 545581.0], [0.9999999999999716, 545581.0]], "data02": [[353.1, 0.0, 1057.3000000000002, 3169.9], [705.2, 0.0, 1409.4, 3522.0], [705.2, 1.0, 1409.4, 3522.0], [353.1, 1.0, 1057.3000000000002, 3169.9]], "data03": [[705.2, 0.0, 1409.4, 1761.5, 2113.600000000001, 2465.7000000000003, 2817.8000000000006], [1057.3000000000002, 0.0, 1761.5, 2113.6000000000004, 2465.7000000000007, 2817.8, 3169.9000000000005], [1057.3000000000002, 0.0, 1761.5, 2113.6000000000004, 2465.7000000000007, 2817.8, 3169.9000000000005], [705.2, 0.0, 1409.4, 1761 ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.5.1.js", function(){
#
#          mpld3.draw_figure("fig_el4788140021753666064745415759", {"width": 864.0, "height": 576.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-175.05000000000004, 3698.05], "ylim": [0.0, 572860.05], "xdomain": [-175.05000000000004, 3698.05], "ydomain": [0.0, 572860.05], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 10, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el4788140021753664784", "lines": [], "paths": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021821324624", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021753663568", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675160656", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data02", "xindex": 2, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675161488", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 2, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675160976", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 3, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675163600", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 4, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675163472", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 5, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021675163536", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 6, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "i

# %%
val_bins, bins = np.histogram(df["size"],bins=np.logspace(1.5,8,num=250))


fig, ax = plt.subplots(figsize=(12,8))

ax.bar(x=bins[:-1], height=val_bins, width=bins[1:] - bins[:-1])
ax.set_xscale('log')
ax.set_xlabel("trade size (log scale)")

ax.set_ylabel("counts")
ax.set_title(f"trade size distributions (counts at the 1 day level)")

mpld3.display(fig)
#plt.savefig("trade_distribution.png")
# Out:
# <style>
#
# </style>
#
# <div id="fig_el47881400217364394406499567369"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el47881400217364394406499567369", {"width": 864.0, "height": 576.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [14.497540659465752, 205203305.0263022], "ylim": [0.0, 13.65], "xdomain": [14.497540659465752, 205203305.0263022], "ydomain": [0.0, 13.65], "xscale": "log", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 11, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "log", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el4788140021753599568", "lines": [], "paths": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021709349008", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021687458640", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021756814416", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data04", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021709214608", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 2, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021709214736", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data05", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021709440272", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021709440464", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data01", "xindex": 2, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021709442192", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data07", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021709329744", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data08", "xindex": 0, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021709331664", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data01", "xindex": 3, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021756898448", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data03", "xindex": 3, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021791302416", "dasharray": "none", "alpha": 1, "facecolor": "#1F77B4", "edgecolor": "none", "edgewidth": 1.0, "zorder": 1}, {"data": "data08", "xindex": 2, "yindex": 1, "coordinates": "data", "pathcodes": ["M", "L", "L", "L", "Z"], "id": "el4788140021684821968", "dasharray": "none", "alpha": 1, "facecolor": "#1F ...

# %%
# ---------------testing---------------
df_feb = df[(df.index > pd.to_datetime("2020-02-01").tz_localize("GMT")) & (df.index < pd.to_datetime("2020-02-28").tz_localize("GMT"))]
df_feb
# Out:
# time
# 2020-02-02 00:00:00+00:00     0
# 2020-02-03 00:00:00+00:00     0
# 2020-02-04 00:00:00+00:00     0
# 2020-02-05 00:00:00+00:00    14
# 2020-02-06 00:00:00+00:00     4
# 2020-02-07 00:00:00+00:00     8
# 2020-02-08 00:00:00+00:00     0
# 2020-02-09 00:00:00+00:00     9
# 2020-02-10 00:00:00+00:00    27
# 2020-02-11 00:00:00+00:00    11
# 2020-02-12 00:00:00+00:00     3
# 2020-02-13 00:00:00+00:00     3
# 2020-02-14 00:00:00+00:00     4
# 2020-02-15 00:00:00+00:00     0
# 2020-02-16 00:00:00+00:00     0
# 2020-02-17 00:00:00+00:00     4
# 2020-02-18 00:00:00+00:00     3
# 2020-02-19 00:00:00+00:00     7
# 2020-02-20 00:00:00+00:00     4
# 2020-02-21 00:00:00+00:00     1
# 2020-02-22 00:00:00+00:00     0
# 2020-02-23 00:00:00+00:00     0
# 2020-02-24 00:00:00+00:00     1
# 2020-02-25 00:00:00+00:00     7
# 2020-02-26 00:00:00+00:00    35
# 2020-02-27 00:00:00+00:00     7
# Name: type, dtype: int64

# %%
dfa = pd.read_csv(f"../data_dumps/BTCM0_Curncy.csv", parse_dates=["time"])
dfa["index"] = dfa.index
dfa = dfa.set_index('time')
dfa.index = dfa.index.tz_localize('UTC')
dfa = dfa[(dfa["type"] == "TRADE") & (dfa["conditionCodes"] == "TSUM")]
dfa
# Out:
#                             type   value  size conditionCodes    index
# time
# 2020-01-03 14:42:08+00:00  TRADE  7490.0     1           TSUM    28175
# 2020-01-03 16:27:56+00:00  TRADE  7650.0     1           TSUM    30151
# 2020-01-07 23:40:38+00:00  TRADE  8470.0     1           TSUM    71570
# 2020-01-09 07:48:11+00:00  TRADE  8195.0     1           TSUM   117305
# 2020-01-10 08:40:52+00:00  TRADE  8005.0     1           TSUM   142223
# ...                          ...     ...   ...            ...      ...
# 2020-06-26 14:58:05+00:00  TRADE  9090.0     1           TSUM  7672229
# 2020-06-26 14:58:05+00:00  TRADE  9090.0     1           TSUM  7672233
# 2020-06-26 14:59:20+00:00  TRADE  9090.0     1           TSUM  7672243
# 2020-06-26 14:59:41+00:00  TRADE  9085.0     1           TSUM  7672248
# 2020-06-26 14:59:43+00:00  TRADE  9085.0     1           TSUM  7672253
#
# [95589 rows x 5 columns]

# %%
dfb = pd.read_csv(f"../data_dumps/BTCN0_Curncy.csv", parse_dates=["time"])
dfb["index"] = dfb.index
dfb = dfb.set_index('time')
dfb.index = dfb.index.tz_localize('UTC')
dfb = dfb[(dfb["type"] == "TRADE") & (dfb["conditionCodes"] == "TSUM")]
dfb
# Out:
#                             type    value  size conditionCodes    index
# time
# 2020-02-11 15:38:37+00:00  TRADE  10685.0     1           TSUM    24715
# 2020-02-11 19:02:32+00:00  TRADE  10920.0     1           TSUM    45611
# 2020-02-13 16:05:23+00:00  TRADE  11060.0     1           TSUM   102778
# 2020-02-27 15:08:32+00:00  TRADE   9180.0     1           TSUM   117449
# 2020-02-27 15:08:32+00:00  TRADE   9180.0     1           TSUM   117455
# ...                          ...      ...   ...            ...      ...
# 2020-07-21 01:12:39+00:00  TRADE   9220.0     1           TSUM  5197887
# 2020-07-21 01:12:39+00:00  TRADE   9220.0     1           TSUM  5197892
# 2020-07-21 01:12:39+00:00  TRADE   9220.0     1           TSUM  5197897
# 2020-07-21 01:13:23+00:00  TRADE   9220.0     1           TSUM  5197945
# 2020-07-21 01:14:36+00:00  TRADE   9215.0     1           TSUM  5197998
#
# [53655 rows x 5 columns]

# %%
dfb_feb = dfb[(dfb.index > pd.to_datetime("2020-02-01").tz_localize("GMT")) & (dfb.index < pd.to_datetime("2020-02-28").tz_localize("GMT"))]
b = dfb_feb.groupby('type').resample('1d').sum()
b
# Out:
#                                    value  size   index
# type  time
# TRADE 2020-02-11 00:00:00+00:00  21605.0     2   70326
#       2020-02-12 00:00:00+00:00      0.0     0       0
#       2020-02-13 00:00:00+00:00  11060.0     1  102778
#       2020-02-14 00:00:00+00:00      0.0     0       0
#       2020-02-15 00:00:00+00:00      0.0     0       0
#       2020-02-16 00:00:00+00:00      0.0     0       0
#       2020-02-17 00:00:00+00:00      0.0     0       0
#       2020-02-18 00:00:00+00:00      0.0     0       0
#       2020-02-19 00:00:00+00:00      0.0     0       0
#       2020-02-20 00:00:00+00:00      0.0     0       0
#       2020-02-21 00:00:00+00:00      0.0     0       0
#       2020-02-22 00:00:00+00:00      0.0     0       0
#       2020-02-23 00:00:00+00:00      0.0     0       0
#       2020-02-24 00:00:00+00:00      0.0     0       0
#       2020-02-25 00:00:00+00:00      0.0     0       0
#       2020-02-26 00:00:00+00:00      0.0     0       0
#       2020-02-27 00:00:00+00:00  18360.0     2  234904

# %%
dfa_feb = dfa[(dfa.index > pd.to_datetime("2020-02-11").tz_localize("GMT")) & (dfa.index < pd.to_datetime("2020-02-28").tz_localize("GMT"))]
a = dfa_feb.groupby('type').resample('1d').sum()
a
# Out:
#                                     value  size     index
# type  time
# TRADE 2020-02-11 00:00:00+00:00   95470.0    11   5959109
#       2020-02-12 00:00:00+00:00   33110.0     3   2154681
#       2020-02-13 00:00:00+00:00   21890.0     2   1454800
#       2020-02-14 00:00:00+00:00   44045.0     4   3093060
#       2020-02-15 00:00:00+00:00       0.0     0         0
#       2020-02-16 00:00:00+00:00       0.0     0         0
#       2020-02-17 00:00:00+00:00   41120.0     4   3119528
#       2020-02-18 00:00:00+00:00   31100.0     4   2366116
#       2020-02-19 00:00:00+00:00   70060.0     7   5570522
#       2020-02-20 00:00:00+00:00   40055.0     4   3212397
#       2020-02-21 00:00:00+00:00   10100.0     1    809882
#       2020-02-22 00:00:00+00:00       0.0     0         0
#       2020-02-23 00:00:00+00:00       0.0     0         0
#       2020-02-24 00:00:00+00:00   10020.0     1    831466
#       2020-02-25 00:00:00+00:00   67970.0     7   5894039
#       2020-02-26 00:00:00+00:00  317480.0    40  30114021
#       2020-02-27 00:00:00+00:00   45490.0     5   4402853

# %%
fd = pd.concat([a,b],axis=0).groupby('time', sort=False)['size'].sum(min_count=1).reset_index()
fd
# Out:
#                         time  size
# 0  2020-02-11 00:00:00+00:00    13
# 1  2020-02-12 00:00:00+00:00     3
# 2  2020-02-13 00:00:00+00:00     3
# 3  2020-02-14 00:00:00+00:00     4
# 4  2020-02-15 00:00:00+00:00     0
# 5  2020-02-16 00:00:00+00:00     0
# 6  2020-02-17 00:00:00+00:00     4
# 7  2020-02-18 00:00:00+00:00     4
# 8  2020-02-19 00:00:00+00:00     7
# 9  2020-02-20 00:00:00+00:00     4
# 10 2020-02-21 00:00:00+00:00     1
# 11 2020-02-22 00:00:00+00:00     0
# 12 2020-02-23 00:00:00+00:00     0
# 13 2020-02-24 00:00:00+00:00     1
# 14 2020-02-25 00:00:00+00:00     7
# 15 2020-02-26 00:00:00+00:00    40
# 16 2020-02-27 00:00:00+00:00     7
